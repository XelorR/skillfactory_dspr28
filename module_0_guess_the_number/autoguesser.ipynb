# %% [markdown]
# # Проект 0. Угадываем загаданное число
#
# в заданном диапозоне и за наименьшее количество попыток

# %%
# используем стандартную библиотеку для генерации случайных целых чисел
# использование numpy считаю избыточным и нецелесообразным
from random import randint

# %% [markdown]
# ## Задаём функцию бинарного поиска
#
# - Всегда указываем ровно в середину диапозона
# - Если попали -- хорошо
# - если наша попытка меньше или больше заданного, отбрасываем соответствующую половину значений и указываем в середину оставшегося диапозона
# - Повтоярем до победного
#
# Угадывает в среднем чуть менее чем за 6 попыток, но никогда не больше 7-и

# %%
def autoguess(number: int, in_range: list):
    print(f"Загадано число от {in_range[0]} до {in_range[-1]}")

    count = 0
    while True:

        # Указываем пальцем ровно в середину диапозона
        guess = (max(in_range) - min(in_range)) // 2 + min(in_range)
        count += 1

        print(f"Попытка номер {count}: {guess}...", end="\t")

        if guess == number:
            print(f"Бинго!\n\nВы угадали число {number} за {count} попыток.")
            return count
        elif number > guess:
            print(f"Угадываемое число больше {guess}")
            in_range[0] = guess + 1  # двигаем нижнюю позицию диапозона
        else:
            print(f"Угадываемое число меньше {guess}")
            in_range[-1] = guess - 1  # двигаем верхнюю границу диапозона

# %% [markdown]
# ## Единичный пример использования функции

# %%
in_range = [1, 100]
number = randint(*in_range)  # загадали число в заданном диапозоне
autoguess(number, in_range)
# Out:
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число больше 75
# Попытка номер 3: 88...	Угадываемое число меньше 88
# Попытка номер 4: 81...	Бинго!
#
# Вы угадали число 81 за 4 попыток.
# 4

# %% [markdown]
# ## Считаем среднюю производительность алгоритма
#
# Среднее арифметическое из 1000 попыток

# %%
thousand_guesses = []
for _ in range(1000):
    thousand_guesses.append(autoguess(randint(1, 100), [1, 100]))
# Out:
# ло меньше 50
# Попытка номер 2: 25...	Угадываемое число больше 25
# Попытка номер 3: 37...	Угадываемое число больше 37
# Попытка номер 4: 43...	Угадываемое число больше 43
# Попытка номер 5: 46...	Угадываемое число меньше 46
# Попытка номер 6: 44...	Бинго!
#
# Вы угадали число 44 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число больше 75
# Попытка номер 3: 88...	Угадываемое число больше 88
# Попытка номер 4: 94...	Угадываемое число меньше 94
# Попытка номер 5: 91...	Угадываемое число меньше 91
# Попытка номер 6: 89...	Угадываемое число больше 89
# Попытка номер 7: 90...	Бинго!
#
# Вы угадали число 90 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число больше 12
# Попытка номер 4: 18...	Угадываемое число меньше 18
# Попытка номер 5: 15...	Угадываемое число больше 15
# Попытка номер 6: 16...	Бинго!
#
# Вы угадали число 16 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число больше 12
# Попытка номер 4: 18...	Угадываемое число меньше 18
# Попытка номер 5: 15...	Угадываемое число больше 15
# Попытка номер 6: 16...	Угадываемое число больше 16
# Попытка номер 7: 17...	Бинго!
#
# Вы угадали число 17 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число больше 25
# Попытка номер 3: 37...	Угадываемое число меньше 37
# Попытка номер 4: 31...	Угадываемое число меньше 31
# Попытка номер 5: 28...	Угадываемое число меньше 28
# Попытка номер 6: 26...	Угадываемое число больше 26
# Попытка номер 7: 27...	Бинго!
#
# Вы угадали число 27 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число больше 12
# Попытка номер 4: 18...	Бинго!
#
# Вы угадали число 18 за 4 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число меньше 12
# Попытка номер 4: 6...	Угадываемое число меньше 6
# Попытка номер 5: 3...	Угадываемое число больше 3
# Попытка номер 6: 4...	Угадываемое число больше 4
# Попытка номер 7: 5...	Бинго!
#
# Вы угадали число 5 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число больше 25
# Попытка номер 3: 37...	Угадываемое число больше 37
# Попытка номер 4: 43...	Угадываемое число больше 43
# Попытка номер 5: 46...	Угадываемое число больше 46
# Попытка номер 6: 48...	Бинго!
#
# Вы угадали число 48 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число больше 25
# Попытка номер 3: 37...	Угадываемое число меньше 37
# Попытка номер 4: 31...	Угадываемое число больше 31
# Попытка номер 5: 34...	Угадываемое число меньше 34
# Попытка номер 6: 32...	Угадываемое число больше 32
# Попытка номер 7: 33...	Бинго!
#
# Вы угадали число 33 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число больше 75
# Попытка номер 3: 88...	Угадываемое число больше 88
# Попытка номер 4: 94...	Угадываемое число больше 94
# Попытка номер 5: 97...	Угадываемое число больше 97
# Попытка номер 6: 99...	Угадываемое число больше 99
# Попытка номер 7: 100...	Бинго!
#
# Вы угадали число 100 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число больше 12
# Попытка номер 4: 18...	Угадываемое число больше 18
# Попытка номер 5: 21...	Угадываемое число меньше 21
# Попытка номер 6: 19...	Угадываемое число больше 19
# Попытка номер 7: 20...	Бинго!
#
# Вы угадали число 20 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число больше 75
# Попытка номер 3: 88...	Угадываемое число больше 88
# Попытка номер 4: 94...	Угадываемое число меньше 94
# Попытка номер 5: 91...	Угадываемое число меньше 91
# Попытка номер 6: 89...	Угадываемое число больше 89
# Попытка номер 7: 90...	Бинго!
#
# Вы угадали число 90 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число больше 75
# Попытка номер 3: 88...	Угадываемое число больше 88
# Попытка номер 4: 94...	Угадываемое число меньше 94
# Попытка номер 5: 91...	Угадываемое число больше 91
# Попытка номер 6: 92...	Бинго!
#
# Вы угадали число 92 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число больше 12
# Попытка номер 4: 18...	Бинго!
#
# Вы угадали число 18 за 4 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число больше 25
# Попытка номер 3: 37...	Угадываемое число больше 37
# Попытка номер 4: 43...	Угадываемое число меньше 43
# Попытка номер 5: 40...	Бинго!
#
# Вы угадали число 40 за 5 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число больше 12
# Попытка номер 4: 18...	Угадываемое число больше 18
# Попытка номер 5: 21...	Угадываемое число больше 21
# Попытка номер 6: 23...	Угадываемое число больше 23
# Попытка номер 7: 24...	Бинго!
#
# Вы угадали число 24 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число больше 25
# Попытка номер 3: 37...	Угадываемое число больше 37
# Попытка номер 4: 43...	Угадываемое число больше 43
# Попытка номер 5: 46...	Угадываемое число больше 46
# Попытка номер 6: 48...	Угадываемое число больше 48
# Попытка номер 7: 49...	Бинго!
#
# Вы угадали число 49 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число больше 25
# Попытка номер 3: 37...	Угадываемое число больше 37
# Попытка номер 4: 43...	Угадываемое число меньше 43
# Попытка номер 5: 40...	Угадываемое число меньше 40
# Попытка номер 6: 38...	Бинго!
#
# Вы угадали число 38 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число больше 25
# Попытка номер 3: 37...	Угадываемое число меньше 37
# Попытка номер 4: 31...	Угадываемое число больше 31
# Попытка номер 5: 34...	Угадываемое число меньше 34
# Попытка номер 6: 32...	Угадываемое число больше 32
# Попытка номер 7: 33...	Бинго!
#
# Вы угадали число 33 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число меньше 75
# Попытка номер 3: 62...	Угадываемое число меньше 62
# Попытка номер 4: 56...	Угадываемое число больше 56
# Попытка номер 5: 59...	Угадываемое число меньше 59
# Попытка номер 6: 57...	Угадываемое число больше 57
# Попытка номер 7: 58...	Бинго!
#
# Вы угадали число 58 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число больше 75
# Попытка номер 3: 88...	Угадываемое число меньше 88
# Попытка номер 4: 81...	Угадываемое число меньше 81
# Попытка номер 5: 78...	Угадываемое число меньше 78
# Попытка номер 6: 76...	Бинго!
#
# Вы угадали число 76 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число меньше 75
# Попытка номер 3: 62...	Угадываемое число больше 62
# Попытка номер 4: 68...	Угадываемое число меньше 68
# Попытка номер 5: 65...	Бинго!
#
# Вы угадали число 65 за 5 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число меньше 12
# Попытка номер 4: 6...	Угадываемое число больше 6
# Попытка номер 5: 9...	Угадываемое число меньше 9
# Попытка номер 6: 7...	Бинго!
#
# Вы угадали число 7 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число меньше 75
# Попытка номер 3: 62...	Угадываемое число больше 62
# Попытка номер 4: 68...	Угадываемое число меньше 68
# Попытка номер 5: 65...	Угадываемое число меньше 65
# Попытка номер 6: 63...	Бинго!
#
# Вы угадали число 63 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число больше 25
# Попытка номер 3: 37...	Угадываемое число меньше 37
# Попытка номер 4: 31...	Угадываемое число больше 31
# Попытка номер 5: 34...	Угадываемое число меньше 34
# Попытка номер 6: 32...	Бинго!
#
# Вы угадали число 32 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число меньше 75
# Попытка номер 3: 62...	Угадываемое число больше 62
# Попытка номер 4: 68...	Угадываемое число меньше 68
# Попытка номер 5: 65...	Угадываемое число больше 65
# Попытка номер 6: 66...	Бинго!
#
# Вы угадали число 66 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число больше 75
# Попытка номер 3: 88...	Угадываемое число больше 88
# Попытка номер 4: 94...	Угадываемое число больше 94
# Попытка номер 5: 97...	Угадываемое число больше 97
# Попытка номер 6: 99...	Угадываемое число меньше 99
# Попытка номер 7: 98...	Бинго!
#
# Вы угадали число 98 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число больше 75
# Попытка номер 3: 88...	Угадываемое число больше 88
# Попытка номер 4: 94...	Угадываемое число меньше 94
# Попытка номер 5: 91...	Угадываемое число больше 91
# Попытка номер 6: 92...	Бинго!
#
# Вы угадали число 92 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число меньше 75
# Попытка номер 3: 62...	Угадываемое число больше 62
# Попытка номер 4: 68...	Угадываемое число меньше 68
# Попытка номер 5: 65...	Угадываемое число больше 65
# Попытка номер 6: 66...	Бинго!
#
# Вы угадали число 66 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число меньше 75
# Попытка номер 3: 62...	Угадываемое число больше 62
# Попытка номер 4: 68...	Угадываемое число меньше 68
# Попытка номер 5: 65...	Бинго!
#
# Вы угадали число 65 за 5 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число меньше 75
# Попытка номер 3: 62...	Угадываемое число больше 62
# Попытка номер 4: 68...	Угадываемое число больше 68
# Попытка номер 5: 71...	Угадываемое число больше 71
# Попытка номер 6: 73...	Угадываемое число больше 73
# Попытка номер 7: 74...	Бинго!
#
# Вы угадали число 74 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число больше 75
# Попытка номер 3: 88...	Угадываемое число меньше 88
# Попытка номер 4: 81...	Угадываемое число больше 81
# Попытка номер 5: 84...	Угадываемое число больше 84
# Попытка номер 6: 86...	Угадываемое число меньше 86
# Попытка номер 7: 85...	Бинго!
#
# Вы угадали число 85 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число больше 25
# Попытка номер 3: 37...	Угадываемое число больше 37
# Попытка номер 4: 43...	Угадываемое число больше 43
# Попытка номер 5: 46...	Угадываемое число больше 46
# Попытка номер 6: 48...	Угадываемое число больше 48
# Попытка номер 7: 49...	Бинго!
#
# Вы угадали число 49 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число больше 12
# Попытка номер 4: 18...	Угадываемое число больше 18
# Попытка номер 5: 21...	Угадываемое число больше 21
# Попытка номер 6: 23...	Угадываемое число больше 23
# Попытка номер 7: 24...	Бинго!
#
# Вы угадали число 24 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число меньше 75
# Попытка номер 3: 62...	Угадываемое число меньше 62
# Попытка номер 4: 56...	Бинго!
#
# Вы угадали число 56 за 4 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число меньше 12
# Попытка номер 4: 6...	Угадываемое число больше 6
# Попытка номер 5: 9...	Бинго!
#
# Вы угадали число 9 за 5 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число меньше 12
# Попытка номер 4: 6...	Угадываемое число больше 6
# Попытка номер 5: 9...	Угадываемое число больше 9
# Попытка номер 6: 10...	Бинго!
#
# Вы угадали число 10 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число меньше 75
# Попытка номер 3: 62...	Угадываемое число больше 62
# Попытка номер 4: 68...	Угадываемое число меньше 68
# Попытка номер 5: 65...	Угадываемое число больше 65
# Попытка номер 6: 66...	Бинго!
#
# Вы угадали число 66 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число меньше 75
# Попытка номер 3: 62...	Угадываемое число больше 62
# Попытка номер 4: 68...	Угадываемое число меньше 68
# Попытка номер 5: 65...	Бинго!
#
# Вы угадали число 65 за 5 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число больше 75
# Попытка номер 3: 88...	Угадываемое число больше 88
# Попытка номер 4: 94...	Угадываемое число больше 94
# Попытка номер 5: 97...	Угадываемое число больше 97
# Попытка номер 6: 99...	Угадываемое число больше 99
# Попытка номер 7: 100...	Бинго!
#
# Вы угадали число 100 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число больше 12
# Попытка номер 4: 18...	Угадываемое число меньше 18
# Попытка номер 5: 15...	Бинго!
#
# Вы угадали число 15 за 5 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число больше 12
# Попытка номер 4: 18...	Угадываемое число меньше 18
# Попытка номер 5: 15...	Угадываемое число больше 15
# Попытка номер 6: 16...	Бинго!
#
# Вы угадали число 16 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число больше 25
# Попытка номер 3: 37...	Угадываемое число больше 37
# Попытка номер 4: 43...	Угадываемое число меньше 43
# Попытка номер 5: 40...	Угадываемое число меньше 40
# Попытка номер 6: 38...	Угадываемое число больше 38
# Попытка номер 7: 39...	Бинго!
#
# Вы угадали число 39 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число меньше 75
# Попытка номер 3: 62...	Угадываемое число больше 62
# Попытка номер 4: 68...	Угадываемое число больше 68
# Попытка номер 5: 71...	Угадываемое число меньше 71
# Попытка номер 6: 69...	Бинго!
#
# Вы угадали число 69 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число меньше 75
# Попытка номер 3: 62...	Угадываемое число меньше 62
# Попытка номер 4: 56...	Угадываемое число больше 56
# Попытка номер 5: 59...	Угадываемое число больше 59
# Попытка номер 6: 60...	Бинго!
#
# Вы угадали число 60 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число больше 25
# Попытка номер 3: 37...	Угадываемое число меньше 37
# Попытка номер 4: 31...	Угадываемое число больше 31
# Попытка номер 5: 34...	Угадываемое число больше 34
# Попытка номер 6: 35...	Угадываемое число больше 35
# Попытка номер 7: 36...	Бинго!
#
# Вы угадали число 36 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число меньше 75
# Попытка номер 3: 62...	Угадываемое число меньше 62
# Попытка номер 4: 56...	Угадываемое число больше 56
# Попытка номер 5: 59...	Угадываемое число больше 59
# Попытка номер 6: 60...	Угадываемое число больше 60
# Попытка номер 7: 61...	Бинго!
#
# Вы угадали число 61 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число больше 75
# Попытка номер 3: 88...	Угадываемое число больше 88
# Попытка номер 4: 94...	Угадываемое число меньше 94
# Попытка номер 5: 91...	Угадываемое число больше 91
# Попытка номер 6: 92...	Угадываемое число больше 92
# Попытка номер 7: 93...	Бинго!
#
# Вы угадали число 93 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число меньше 12
# Попытка номер 4: 6...	Угадываемое число меньше 6
# Попытка номер 5: 3...	Бинго!
#
# Вы угадали число 3 за 5 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число больше 12
# Попытка номер 4: 18...	Угадываемое число больше 18
# Попытка номер 5: 21...	Бинго!
#
# Вы угадали число 21 за 5 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число меньше 25
# Попытка номер 3: 12...	Угадываемое число меньше 12
# Попытка номер 4: 6...	Угадываемое число меньше 6
# Попытка номер 5: 3...	Угадываемое число меньше 3
# Попытка номер 6: 1...	Угадываемое число больше 1
# Попытка номер 7: 2...	Бинго!
#
# Вы угадали число 2 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число больше 75
# Попытка номер 3: 88...	Угадываемое число меньше 88
# Попытка номер 4: 81...	Угадываемое число меньше 81
# Попытка номер 5: 78...	Угадываемое число меньше 78
# Попытка номер 6: 76...	Угадываемое число больше 76
# Попытка номер 7: 77...	Бинго!
#
# Вы угадали число 77 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число больше 25
# Попытка номер 3: 37...	Угадываемое число меньше 37
# Попытка номер 4: 31...	Угадываемое число меньше 31
# Попытка номер 5: 28...	Угадываемое число меньше 28
# Попытка номер 6: 26...	Угадываемое число больше 26
# Попытка номер 7: 27...	Бинго!
#
# Вы угадали число 27 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число меньше 75
# Попытка номер 3: 62...	Угадываемое число меньше 62
# Попытка номер 4: 56...	Угадываемое число меньше 56
# Попытка номер 5: 53...	Угадываемое число больше 53
# Попытка номер 6: 54...	Бинго!
#
# Вы угадали число 54 за 6 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число больше 50
# Попытка номер 2: 75...	Угадываемое число больше 75
# Попытка номер 3: 88...	Угадываемое число меньше 88
# Попытка номер 4: 81...	Угадываемое число меньше 81
# Попытка номер 5: 78...	Угадываемое число меньше 78
# Попытка номер 6: 76...	Угадываемое число больше 76
# Попытка номер 7: 77...	Бинго!
#
# Вы угадали число 77 за 7 попыток.
# Загадано число от 1 до 100
# Попытка номер 1: 50...	Угадываемое число меньше 50
# Попытка номер 2: 25...	Угадываемое число больше 25
# Попытка номер 3: 37...	Угадываемое число меньше 37
# Попытка номер 4: 31...	Угадываемое число меньше 31
# Попытка номер 5: 28...	Угадываемое число меньше 28
# Попытка номер 6: 26...	Угадываемое число больше 26
# Попытка номер 7: 27...	Бинго!
#
# Вы угадали число 27 за 7 попыток.

# %%
print(
    "В среднем мы угадываем за",
    sum(thousand_guesses) / len(thousand_guesses),
    "попыток",
)
# Out:
# В среднем мы угадываем за 5.815 попыток
